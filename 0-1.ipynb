# %%
import pandas as pd
try:
    con_trend = pd.read_csv(r'c:\Users\박중현\Desktop\소비트렌드 분석\data\2021_분기자료(신항목분류, 2019~) - 비농림어가_1인이상_20251112_56930.csv', encoding='cp949', low_memory=False)
except Exception as e:
    print(e)
    
print(con_trend.columns)
con_trend.info()
# Out:
# Index(['조사연월', '가구원수', '가구주_관계코드', '가구주_성별코드', '가구주_연령', '소득_경상소득_재산소득_이자소득',
#        '소득_경상소득_재산소득_배당소득', '소득_경상소득', '소득_경상소득_이전소득_할인혜택금액',
#        '소득_경상소득_재산소득_기타재산소득',
#        ...
#        '가계지출_소비지출_기타상품서비스_기타금융구입비', '가계지출_소비지출_기타상품서비스_이미용서비스이용금액',
#        '가계지출_소비지출_기타상품서비스_이미용기기구입비', '가계지출_소비지출_기타상품서비스_위생이미용용품구입비',
#        '가계지출_소비지출_기타상품서비스_시계장신구구입비', '가계지출_소비지출_기타상품서비스_기타개인용품구입비',
#        '가계지출_소비지출_기타상품서비스_복지시설비용금액', '가계지출_소비지출_기타상품서비스_기타서비스금액구입비',
#        '도시읍면부구분코드', '가구일련번호'],
#       dtype='object', length=125)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23591 entries, 0 to 23590
# Columns: 125 entries, 조사연월 to 가구일련번호
# dtypes: int64(125)
# memory usage: 22.5 MB
