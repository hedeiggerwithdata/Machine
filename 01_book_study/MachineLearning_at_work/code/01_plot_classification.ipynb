# %%
import sklearn.model_selection import train_test_split


def plot_result(clf, clf_name, df, color=False): #clf: 분류 모델, clf_name: 그레프 제목(모델 이름), df: 데이터프레임, color: 색깔 여부
    # <목적>
    # 데이터 산점도
    # 모델 분류 영역
    # 테스트 정확도
    # 모델이름
    
    plt.rcparams['font.size'] = 16
    
    X = df[['x', 'y']]
    Y = df['label']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)
# Out:
# Failed to start the Kernel 'Python 3.14.0'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. listen EFAULT: bad address in system call argument :::9000
