# %%
import json
import pandas as pd
from io import StringIO

d3 = json.dumps([{"name": "체인소맨", "author": "후지모토 타츠키", "발행연도": 2022},
                {"name": "체인소맨 레제편", "author": ["후지모토 타츠키", "김경식"], "발행연도": 2025 }])
d4 = json.loads(d3)
pd.DataFrame(d4)
# Out:
#        name           author  발행연도
# 0      체인소맨         후지모토 타츠키  2022
# 1  체인소맨 레제편  [후지모토 타츠키, 김경식]  2025
