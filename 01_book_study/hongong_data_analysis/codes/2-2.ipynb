# %%
import xml.etree.ElementTree as et
import pandas as pd

x_str = """
<books>
    <book>
        <name> 체인소맨 </name>
        <author> 후지모토 타츠키 </author>
        <year> 2022 </year>
    </book>
    <book>
        <name> 체인소맨 레제편 </name>
        <author> 후지모토 타츠키 외 1인 </author>
        <year> 2025 </year>
    </book>
</books>"""
    
df = pd.read_xml(x_str)
df.head()

# for book in books.findall('book'):
#     author = book.findtext('author')
#     name = book.findtext('name')
#     year = book.findtext('year')
#     print(author)
#     print(name)
#     print(year)
#     print()
# Out:
# C:\Users\박중현\AppData\Local\Temp\ipykernel_20276\3814671124.py:18: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(x_str)
#          name           author  year
# 0       체인소맨         후지모토 타츠키   2022
# 1   체인소맨 레제편    후지모토 타츠키 외 1인   2025
