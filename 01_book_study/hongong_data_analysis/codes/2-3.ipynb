# %%
import requests
import pandas as pd

url = "http://data4library.kr/api/loanItemSrch?format=json&startDt=2025-01-01&endDt=2025-12-31&age=20&authKey=d1cb2a6f128174a390886e6c8e0fb547df5f3fec177e86146e84f4174312b5de"
r = requests.get(url)
data = r.json()

book_list = [b['doc'] for b in data['response']['docs']]
book_df = pd.DataFrame(book_list)
book_df.to_csv('20s_book_2025.csv', encoding = 'utf-8')
book_df
# Out:
#       no ranking                         bookname                  authors  \
# 0      1       1                 소년이 온다 :한강 장편소설                   지은이: 한강
# 1      2       2                    모순 :양귀자 장편소설                  지은이: 양귀자
# 2      3       3               작별하지 않는다 :한강 장편소설                   지은이: 한강
# 3      4       4                홍학의 자리 :정해연 장편소설                  지은이: 정해연
# 4      5       5     나는 소망한다 내게 금지된 것을 :양귀자 장편소설                  지은이: 양귀자
# ..   ...     ...                              ...                      ...
# 195  196     196                포스트맨은 벨을 두 번 울린다    제임스 M. 케인 [지음] ;이만식 옮김
# 196  197     197        노르웨이의 숲 =Noruuei no mori   지은이: 무라카미 하루키 ;옮긴이: 양억관
# 197  198     198                         이기적 유전자        리처드 도킨스 지음 ;이상임 옮김
# 198  199     198  숨결이 바람 될 때 :서른여섯 젊은 의사의 마지막 순간         폴 칼라니티 지음 ;이종인 옮김
# 199  200     200                스토너 :존 윌리엄스 장편소설     지은이: 존 윌리엄스 ;옮긴이: 김승욱
#
# ...
